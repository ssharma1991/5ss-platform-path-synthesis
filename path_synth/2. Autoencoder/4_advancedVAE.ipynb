# %% [markdown]
# # Conditional Variational Autoencoder (CVAE)

# %%
# Conditional VAE
# for path completion
# Train using mask and respective incomplete paths as input and full path as output.
def CVAE_Z30():
    z_dim=30
    inp=Input(shape=(100,3))
    condition=Input(shape=(100,1))

    # Encoding
    inp_cond= Concatenate()([inp, condition])
    x= Reshape((100, 4, 1))(inp_cond)
    x= Conv2D(15, (10,1), strides=(10, 1), activation='relu')(x)
    x= Conv2D(20, (2,1), strides=(2, 1), activation='relu')(x)
    x= Conv2D(25, (4,1), activation='relu')(x)
    x= Flatten()(x)
    x=Dense(90, activation='relu')(x)
    x=Dense(70, activation='relu')(x)
    x=Dense(50, activation='relu')(x)
    z_mean = Dense(z_dim, name='z_mean')(x)
    z_log_var = Dense(z_dim, name='z_log_var')(x)
    z = Lambda(sampling, output_shape=(z_dim,), name='z')([z_mean, z_log_var])

    # Decoding
    z = Reshape((z_dim, 1))(z)
    z_cond = Concatenate(axis=-2)([z, condition])
    x=Flatten()(z_cond)
    x=Dense(50, activation='relu')(x)
    x=Dense(70, activation='relu')(x)
    x=Dense(90, activation='relu')(x)
    x=Dense(150, activation='relu')(x)
    x= Reshape((2, 3, 25))(x)
    x= Conv2DTranspose(20, (4,1), activation='relu')(x)
    x= Conv2DTranspose(15, (2,1), strides=(2, 1), activation='relu')(x)
    x= Conv2DTranspose(1, (10,1), strides=(10, 1))(x)
    y= Reshape((100, 3))(x)
    
    # loss
    def reconstruction_loss(out_true, out_pred):
      return rmse(out_true, out_pred)
    def kl_loss(out_true, out_pred):
      return .1*kl(z_mean,z_log_var)
    def vae_loss(out_true, out_pred):   
      return reconstruction_loss(out_true, out_pred) + kl_loss(out_true, out_pred)

    # build model
    cvae = Model(inputs=[inp,condition], outputs=[y])
    #cvae.add_loss(vae_loss)
    cvae.compile(optimizer='adam', loss=vae_loss, metrics=[reconstruction_loss,kl_loss])
    cvae.summary()
    
    encoder = Model(inputs=[inp,condition], outputs=[z_mean])
    return cvae, encoder

cvae,_=CVAE_Z30()
SVG(model_to_dot(cvae, show_shapes='true', show_layer_names='true', dpi=70).create(prog='dot', format='svg'))
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_15 (InputLayer)           (None, 100, 3)       0
# __________________________________________________________________________________________________
# input_16 (InputLayer)           (None, 100, 1)       0
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 100, 4)       0           input_15[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# reshape_23 (Reshape)            (None, 100, 4, 1)    0           concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 10, 4, 15)    165         reshape_23[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 5, 4, 20)     620         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 4, 25)     2025        conv2d_23[0][0]
# __________________________________________________________________________________________________
# flatten_13 (Flatten)            (None, 200)          0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# dense_42 (Dense)                (None, 90)           18090       flatten_13[0][0]
# __________________________________________________________________________________________________
# dense_43 (Dense)                (None, 90)           8190        dense_42[0][0]
# __________________________________________________________________________________________________
# dense_44 (Dense)                (None, 90)           8190        dense_43[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 30)           2730        dense_44[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 30)           2730        dense_44[0][0]
# __________________________________________________________________________________________________
# z (Lambda)                      (None, 30)           0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# reshape_24 (Reshape)            (None, 30, 1)        0           z[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 130, 1)       0           reshape_24[0][0]
#                                                                  input_16[0][0]
# __________________________________________________________________________________________________
# flatten_14 (Flatten)            (None, 130)          0           concatenate_14[0][0]
# __________________________________________________________________________________________________
# dense_45 (Dense)                (None, 90)           11790       flatten_14[0][0]
# __________________________________________________________________________________________________
# dense_46 (Dense)                (None, 90)           8190        dense_45[0][0]
# __________________________________________________________________________________________________
# dense_47 (Dense)                (None, 90)           8190        dense_46[0][0]
# __________________________________________________________________________________________________
# dense_48 (Dense)                (None, 150)          13650       dense_47[0][0]
# __________________________________________________________________________________________________
# reshape_25 (Reshape)            (None, 2, 3, 25)     0           dense_48[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_16 (Conv2DTran (None, 5, 3, 20)     2020        reshape_25[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_17 (Conv2DTran (None, 10, 3, 15)    615         conv2d_transpose_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_18 (Conv2DTran (None, 100, 3, 1)    151         conv2d_transpose_17[0][0]
# __________________________________________________________________________________________________
# reshape_26 (Reshape)            (None, 100, 3)       0           conv2d_transpose_18[0][0]
# ==================================================================================================
# Total params: 87,346
# Trainable params: 87,346
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
current_dir=os.getcwd()
db_path=os.path.join(current_dir,'..','1. DB Preprocessing','db6_5SS_noisy_s60252.npz')
db = np.load(db_path)
cplr_noisy=db['cplrData']
cplr_mask=np.expand_dims(db['cplrMask'], axis=-1)
print(cplr_noisy.shape)
print(cplr_mask.shape)

cplr_mir = import_DB('db4_5SS_mirror_s20084.npz')
db_part=[]
n_partial=2
for i in range(cplr_mir.shape[0]):
  for j in range(n_partial):
    db_part.append(cplr_mir[i])
cplr_true=np.append(cplr_mir,np.array(db_part),axis=0)
print(cplr_true.shape)
# Out:
# (60252, 100, 3)
# (60252, 100, 1)
# (60252, 100, 3)

# %%
data_max=np.max([np.max(cplr_noisy),np.max(cplr_true)])
data_min=np.min([np.min(cplr_noisy),np.min(cplr_true)])
print(data_max)
print(np.abs(data_min))
# Out:
# 0.5583904768264918
# 0.5764223109354129

# %%
# Renormalize DB from range [-1,1] to range [0,1] 
n_cplr_true=cplr_true/(np.abs(data_min)+data_max)+np.abs(data_min)
n_cplr_noisy=cplr_noisy/(np.abs(data_min)+data_max)+np.abs(data_min)

# %%
x= n_cplr_noisy
y= n_cplr_true
mask=cplr_mask

# Split data into training and testing dataset
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test, m_train, m_test = train_test_split(x, y, mask, test_size=0.2, random_state=1)

print(x_train.shape)
print(y_train.shape)
print(m_train.shape)
print(x_test.shape)
print(y_test.shape)
print(m_test.shape)
# Out:
# (48201, 100, 3)
# (48201, 100, 3)
# (48201, 100, 1)
# (12051, 100, 3)
# (12051, 100, 3)
# (12051, 100, 1)

# %%
train_data=cvae.fit([x_train,m_train], [y_train], shuffle=True, epochs=50, batch_size=128, validation_data=([x_test,m_test], [y_test]), verbose=1)
# Out:
# Train on 48201 samples, validate on 12051 samples
# Epoch 1/50
# 48201/48201 [==============================] - 4s 91us/step - loss: 3.3432 - reconstruction_loss: 2.7580 - kl_loss: 0.5852 - val_loss: 3.4118 - val_reconstruction_loss: 2.8286 - val_kl_loss: 0.5833
# Epoch 2/50
# 48201/48201 [==============================] - 4s 93us/step - loss: 3.3256 - reconstruction_loss: 2.7375 - kl_loss: 0.5881 - val_loss: 3.3651 - val_reconstruction_loss: 2.7731 - val_kl_loss: 0.5920
# Epoch 3/50
# 48201/48201 [==============================] - 5s 111us/step - loss: 3.3255 - reconstruction_loss: 2.7383 - kl_loss: 0.5872 - val_loss: 3.4466 - val_reconstruction_loss: 2.8622 - val_kl_loss: 0.5843
# Epoch 4/50
# 48201/48201 [==============================] - 5s 103us/step - loss: 3.3240 - reconstruction_loss: 2.7368 - kl_loss: 0.5872 - val_loss: 3.3826 - val_reconstruction_loss: 2.7867 - val_kl_loss: 0.5959
# Epoch 5/50
# 48201/48201 [==============================] - 5s 99us/step - loss: 3.3093 - reconstruction_loss: 2.7199 - kl_loss: 0.5893 - val_loss: 3.3940 - val_reconstruction_loss: 2.7959 - val_kl_loss: 0.5981
# Epoch 6/50
# 48201/48201 [==============================] - 5s 107us/step - loss: 3.3132 - reconstruction_loss: 2.7244 - kl_loss: 0.5888 - val_loss: 3.3945 - val_reconstruction_loss: 2.8104 - val_kl_loss: 0.5841
# Epoch 7/50
# 48201/48201 [==============================] - 5s 103us/step - loss: 3.3135 - reconstruction_loss: 2.7249 - kl_loss: 0.5886 - val_loss: 3.3471 - val_reconstruction_loss: 2.7566 - val_kl_loss: 0.5905
# Epoch 8/50
# 48201/48201 [==============================] - 5s 110us/step - loss: 3.3107 - reconstruction_loss: 2.7209 - kl_loss: 0.5898 - val_loss: 3.3897 - val_reconstruction_loss: 2.7921 - val_kl_loss: 0.5976
# Epoch 9/50
# 48201/48201 [==============================] - 5s 97us/step - loss: 3.3128 - reconstruction_loss: 2.7235 - kl_loss: 0.5893 - val_loss: 3.3648 - val_reconstruction_loss: 2.7674 - val_kl_loss: 0.5974
# Epoch 10/50
# 48201/48201 [==============================] - 5s 101us/step - loss: 3.2980 - reconstruction_loss: 2.7088 - kl_loss: 0.5892 - val_loss: 3.3750 - val_reconstruction_loss: 2.7884 - val_kl_loss: 0.5866
# Epoch 11/50
# 48201/48201 [==============================] - 5s 105us/step - loss: 3.2931 - reconstruction_loss: 2.7039 - kl_loss: 0.5891 - val_loss: 3.3858 - val_reconstruction_loss: 2.7827 - val_kl_loss: 0.6031
# Epoch 12/50
# 48201/48201 [==============================] - 5s 101us/step - loss: 3.2996 - reconstruction_loss: 2.7106 - kl_loss: 0.5891 - val_loss: 3.4189 - val_reconstruction_loss: 2.8328 - val_kl_loss: 0.5861
# Epoch 13/50
# 48201/48201 [==============================] - 5s 96us/step - loss: 3.2885 - reconstruction_loss: 2.6974 - kl_loss: 0.5912 - val_loss: 3.3858 - val_reconstruction_loss: 2.7974 - val_kl_loss: 0.5884
# Epoch 14/50
# 48201/48201 [==============================] - 5s 95us/step - loss: 3.2886 - reconstruction_loss: 2.6986 - kl_loss: 0.5900 - val_loss: 3.3988 - val_reconstruction_loss: 2.8158 - val_kl_loss: 0.5830
# Epoch 15/50
# 48201/48201 [==============================] - 5s 94us/step - loss: 3.2959 - reconstruction_loss: 2.7070 - kl_loss: 0.5889 - val_loss: 3.4007 - val_reconstruction_loss: 2.8090 - val_kl_loss: 0.5917
# Epoch 16/50
# 48201/48201 [==============================] - 4s 90us/step - loss: 3.2896 - reconstruction_loss: 2.6984 - kl_loss: 0.5912 - val_loss: 3.4050 - val_reconstruction_loss: 2.8331 - val_kl_loss: 0.5718
# Epoch 17/50
# 48201/48201 [==============================] - 5s 94us/step - loss: 3.2933 - reconstruction_loss: 2.7031 - kl_loss: 0.5902 - val_loss: 3.3738 - val_reconstruction_loss: 2.7826 - val_kl_loss: 0.5912
# Epoch 18/50
# 48201/48201 [==============================] - 5s 100us/step - loss: 3.2771 - reconstruction_loss: 2.6870 - kl_loss: 0.5901 - val_loss: 3.3918 - val_reconstruction_loss: 2.8020 - val_kl_loss: 0.5897
# Epoch 19/50
# 48201/48201 [==============================] - 5s 98us/step - loss: 3.2846 - reconstruction_loss: 2.6952 - kl_loss: 0.5894 - val_loss: 3.3799 - val_reconstruction_loss: 2.7763 - val_kl_loss: 0.6036
# Epoch 20/50
# 48201/48201 [==============================] - 5s 95us/step - loss: 3.2847 - reconstruction_loss: 2.6928 - kl_loss: 0.5918 - val_loss: 3.3523 - val_reconstruction_loss: 2.7686 - val_kl_loss: 0.5837
# Epoch 21/50
# 48201/48201 [==============================] - 5s 97us/step - loss: 3.2852 - reconstruction_loss: 2.6962 - kl_loss: 0.5890 - val_loss: 3.4050 - val_reconstruction_loss: 2.8257 - val_kl_loss: 0.5793
# Epoch 22/50
# 48201/48201 [==============================] - 5s 94us/step - loss: 3.2887 - reconstruction_loss: 2.6989 - kl_loss: 0.5899 - val_loss: 3.3875 - val_reconstruction_loss: 2.8006 - val_kl_loss: 0.5870
# Epoch 23/50
# 48201/48201 [==============================] - 5s 96us/step - loss: 3.2849 - reconstruction_loss: 2.6944 - kl_loss: 0.5905 - val_loss: 3.3429 - val_reconstruction_loss: 2.7453 - val_kl_loss: 0.5977
# Epoch 24/50
# 48201/48201 [==============================] - 5s 110us/step - loss: 3.2492 - reconstruction_loss: 2.6567 - kl_loss: 0.5925 - val_loss: 3.3396 - val_reconstruction_loss: 2.7512 - val_kl_loss: 0.5884
# Epoch 25/50
# 48201/48201 [==============================] - 5s 110us/step - loss: 3.2613 - reconstruction_loss: 2.6705 - kl_loss: 0.5909 - val_loss: 3.3711 - val_reconstruction_loss: 2.7765 - val_kl_loss: 0.5946
# Epoch 26/50
# 48201/48201 [==============================] - 5s 109us/step - loss: 3.2675 - reconstruction_loss: 2.6770 - kl_loss: 0.5905 - val_loss: 3.3556 - val_reconstruction_loss: 2.7731 - val_kl_loss: 0.5825
# Epoch 27/50
# 48201/48201 [==============================] - 5s 108us/step - loss: 3.2514 - reconstruction_loss: 2.6592 - kl_loss: 0.5922 - val_loss: 3.3613 - val_reconstruction_loss: 2.7694 - val_kl_loss: 0.5919
# Epoch 28/50
# 48201/48201 [==============================] - 5s 101us/step - loss: 3.2499 - reconstruction_loss: 2.6567 - kl_loss: 0.5932 - val_loss: 3.3230 - val_reconstruction_loss: 2.7140 - val_kl_loss: 0.6090
# Epoch 29/50
# 48201/48201 [==============================] - 5s 108us/step - loss: 3.2572 - reconstruction_loss: 2.6651 - kl_loss: 0.5921 - val_loss: 3.3889 - val_reconstruction_loss: 2.7942 - val_kl_loss: 0.5947
# Epoch 30/50
# 48201/48201 [==============================] - 5s 101us/step - loss: 3.2617 - reconstruction_loss: 2.6701 - kl_loss: 0.5916 - val_loss: 3.3486 - val_reconstruction_loss: 2.7589 - val_kl_loss: 0.5897
# Epoch 31/50
# 48201/48201 [==============================] - 4s 92us/step - loss: 3.2473 - reconstruction_loss: 2.6547 - kl_loss: 0.5927 - val_loss: 3.3133 - val_reconstruction_loss: 2.7218 - val_kl_loss: 0.5914
# Epoch 32/50
# 48201/48201 [==============================] - 5s 101us/step - loss: 3.2451 - reconstruction_loss: 2.6519 - kl_loss: 0.5931 - val_loss: 3.3461 - val_reconstruction_loss: 2.7566 - val_kl_loss: 0.5894
# Epoch 33/50
# 48201/48201 [==============================] - 5s 107us/step - loss: 3.2435 - reconstruction_loss: 2.6504 - kl_loss: 0.5931 - val_loss: 3.3118 - val_reconstruction_loss: 2.7149 - val_kl_loss: 0.5969
# Epoch 34/50
# 48201/48201 [==============================] - 5s 98us/step - loss: 3.2553 - reconstruction_loss: 2.6616 - kl_loss: 0.5937 - val_loss: 3.3418 - val_reconstruction_loss: 2.7422 - val_kl_loss: 0.5996
# Epoch 35/50
# 48201/48201 [==============================] - 5s 93us/step - loss: 3.2539 - reconstruction_loss: 2.6621 - kl_loss: 0.5918 - val_loss: 3.3282 - val_reconstruction_loss: 2.7421 - val_kl_loss: 0.5861
# Epoch 36/50
# 48201/48201 [==============================] - 5s 94us/step - loss: 3.2404 - reconstruction_loss: 2.6490 - kl_loss: 0.5914 - val_loss: 3.3177 - val_reconstruction_loss: 2.7174 - val_kl_loss: 0.6002
# Epoch 37/50
# 48201/48201 [==============================] - 5s 97us/step - loss: 3.2328 - reconstruction_loss: 2.6387 - kl_loss: 0.5940 - val_loss: 3.3377 - val_reconstruction_loss: 2.7463 - val_kl_loss: 0.5914
# Epoch 38/50
# 48201/48201 [==============================] - 4s 91us/step - loss: 3.2374 - reconstruction_loss: 2.6439 - kl_loss: 0.5935 - val_loss: 3.3564 - val_reconstruction_loss: 2.7715 - val_kl_loss: 0.5850
# Epoch 39/50
# 48201/48201 [==============================] - 4s 90us/step - loss: 3.2441 - reconstruction_loss: 2.6502 - kl_loss: 0.5939 - val_loss: 3.3842 - val_reconstruction_loss: 2.7915 - val_kl_loss: 0.5927
# Epoch 40/50
# 48201/48201 [==============================] - 4s 91us/step - loss: 3.2267 - reconstruction_loss: 2.6331 - kl_loss: 0.5936 - val_loss: 3.3395 - val_reconstruction_loss: 2.7305 - val_kl_loss: 0.6091
# Epoch 41/50
# 48201/48201 [==============================] - 4s 91us/step - loss: 3.2329 - reconstruction_loss: 2.6386 - kl_loss: 0.5943 - val_loss: 3.3253 - val_reconstruction_loss: 2.7353 - val_kl_loss: 0.5901
# Epoch 42/50
# 48201/48201 [==============================] - 4s 86us/step - loss: 3.2286 - reconstruction_loss: 2.6350 - kl_loss: 0.5936 - val_loss: 3.3283 - val_reconstruction_loss: 2.7386 - val_kl_loss: 0.5897
# Epoch 43/50
# 48201/48201 [==============================] - 4s 91us/step - loss: 3.2251 - reconstruction_loss: 2.6309 - kl_loss: 0.5943 - val_loss: 3.3470 - val_reconstruction_loss: 2.7569 - val_kl_loss: 0.5901
# Epoch 44/50
# 48201/48201 [==============================] - 4s 91us/step - loss: 3.2327 - reconstruction_loss: 2.6378 - kl_loss: 0.5949 - val_loss: 3.3065 - val_reconstruction_loss: 2.7175 - val_kl_loss: 0.5890
# Epoch 45/50
# 48201/48201 [==============================] - 4s 87us/step - loss: 3.2445 - reconstruction_loss: 2.6505 - kl_loss: 0.5940 - val_loss: 3.3140 - val_reconstruction_loss: 2.7102 - val_kl_loss: 0.6038
# Epoch 46/50
# 48201/48201 [==============================] - 4s 84us/step - loss: 3.2330 - reconstruction_loss: 2.6389 - kl_loss: 0.5941 - val_loss: 3.3081 - val_reconstruction_loss: 2.7108 - val_kl_loss: 0.5973
# Epoch 47/50
# 48201/48201 [==============================] - 4s 89us/step - loss: 3.2215 - reconstruction_loss: 2.6271 - kl_loss: 0.5944 - val_loss: 3.2939 - val_reconstruction_loss: 2.7073 - val_kl_loss: 0.5866
# Epoch 48/50
# 48201/48201 [==============================] - 4s 85us/step - loss: 3.2260 - reconstruction_loss: 2.6310 - kl_loss: 0.5950 - val_loss: 3.2800 - val_reconstruction_loss: 2.6932 - val_kl_loss: 0.5868
# Epoch 49/50
# 48201/48201 [==============================] - 4s 85us/step - loss: 3.2214 - reconstruction_loss: 2.6267 - kl_loss: 0.5947 - val_loss: 3.3076 - val_reconstruction_loss: 2.7084 - val_kl_loss: 0.5992
# Epoch 50/50
# 48201/48201 [==============================] - 4s 89us/step - loss: 3.2138 - reconstruction_loss: 2.6187 - kl_loss: 0.5951 - val_loss: 3.3216 - val_reconstruction_loss: 2.7237 - val_kl_loss: 0.5979

# %%
visualize_train_curves(train_data)
# Out:
# Training loss: 3.2138
# Validation loss: 3.3216

# %%
# %matplotlib inline
#%matplotlib notebook

import numpy as np 
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
from numpy import linalg as LA
#plt.style.use('dark_background')


def plotPath3D(Pts, ax, limit, color = 'gray'):
    xline=Pts[:,0]
    yline=Pts[:,1]
    zline=Pts[:,2]
    ax.plot3D(xline, yline, zline, color)
    ax.auto_scale_xyz([-limit, limit], [-limit, limit], [-limit, limit])
    plt.tight_layout()

def plotPath(Pts, ax, limit, color = 'gray'):
    xline=Pts[:,0]
    yline=Pts[:,1]
    ax.plot(xline, yline, color)
    ax.set(xlim=(0, limit), ylim=(0, limit))

def plotXYZ(center, RotMat, ax):
    C=np.vstack((center,center,center))
    R=RotMat
    r=(1,0,0)
    g=(0,1,0)
    b=(0,0,1)
    ax.quiver(C[:,0], C[:,1], C[:,2], R[:,0], R[:,1], R[:,2],color=(r,g,b,r,r,g,g,b,b))
    plt.tight_layout()


def visualizePaths(Paths,rows=10,cols=3, axlimit=.5):
    path_index=0;
    fig = plt.figure(figsize=2*plt.figaspect(rows/cols))
    for i in range(rows):
        for j in range(cols):
            Pts=Paths[path_index]
            path_index=path_index+1
            ax = fig.add_subplot(rows, cols, path_index, projection='3d')
            plotPath(Pts, ax, axlimit)
            #plotXYZ(np.zeros((1, 3)), np.identity(3), ax)
    plt.tight_layout()
    plt.show()

def visualizePathsRand(Paths,rows=10,cols=3, axlimit=.5):
    path_index=0;
    fig = plt.figure(figsize=2*plt.figaspect(rows/cols))
    for i in range(rows):
        for j in range(cols):
            Pts=Paths[np.random.randint(Paths.shape[0])]
            path_index=path_index+1
            ax = fig.add_subplot(rows, cols, path_index, projection='3d')
            plotPath(Pts, ax, axlimit)
            #plotXYZ(np.zeros((1, 3)), np.identity(3), ax)
    plt.tight_layout()
    plt.show()

# %%
reconst_curve = cvae.predict([x_train,m_train])

# %%
def plotPartialPath(Pts, mask, ax, limit, color = 'gray'):
    ind=np.nonzero(mask)
    xline=Pts[:,0]
    yline=Pts[:,1]
    zline=Pts[:,2]
    ax.plot3D(xline[ind[0]], yline[ind[0]], zline[ind[0]], color)
    ax.auto_scale_xyz([0, limit], [0, limit], [0, limit])
    plt.tight_layout()


i=4
orig=y_train[i]
recon=reconst_curve[i]

fig= plt.figure(figsize=(16, 4))
ax = plt.subplot(1, 4, 1, projection='3d')
#3D view
plotPath3D(reconst_curve[i],ax,1,'r')
plotPath3D(y_train[i],ax,1,'g')
plotPartialPath(x_train[i],m_train[i],ax,1)

#x-y, x-z, y-z plane view
xy_recon=recon[:,0:2]
xy_orig=orig[:,0:2]
xz_recon=np.concatenate(([recon[:,0]], [recon[:,2]]),axis=0).T
xz_orig=np.concatenate(([orig[:,0]], [orig[:,2]]),axis=0).T
yz_recon=recon[:,1:3]
yz_orig=orig[:,1:3]

# Top View
ax = plt.subplot(1, 4, 2)
plotPath(xy_recon, ax, 1,'r' )
plotPath(xy_orig, ax, 1)
    
# Front View
ax = plt.subplot(1, 4, 3)
plotPath(xz_recon, ax, 1,'r' )
plotPath(xz_orig, ax, 1)
       
# Right View
ax = plt.subplot(1, 4, 4)
plotPath(yz_recon, ax, 1,'r' )
plotPath(yz_orig, ax, 1)

plt.show()

# %% [markdown]
# # Shared-encoder CVAE

# %%
# Shared Encoder CVAE
# Has single encoder and multiple decoders
# Used to generate DeepFake/FaceSwap

def SE_CVAE_encoder():
    z_dim=30
    inp=Input(shape=(100,3))
    condition=Input(shape=(100,1))

    # Encoding
    inp_cond= Concatenate()([inp, condition])
    x=Flatten()(inp_cond)
    x=Dense(150, activation='relu')(x)
    x=Dense(150, activation='relu')(x)
    x=Dense(150, activation='relu')(x)
    z_mean = Dense(z_dim, name='z_mean')(x)
    z_log_var = Dense(z_dim, name='z_log_var')(x)
    z = Lambda(sampling, output_shape=(z_dim,), name='z')([z_mean, z_log_var])
    z = Reshape((z_dim, 1))(z)
    
    return Model(inputs=[inp,condition], outputs=[z,z_mean,z_log_var])
    
def SE_CVAE_decoder():
    z_dim=30
    z=Input(shape=(z_dim,1))
    condition=Input(shape=(100,1))

    # Encoding
    z_cond = Concatenate(axis=-2)([z, condition])
    x=Flatten()(z_cond)
    x=Dense(150, activation='relu')(x)
    x=Dense(150, activation='relu')(x)
    x=Dense(150, activation='relu')(x)
    x=Dense(300)(x)
    y=Reshape((100, 3))(x)
    
    return Model(inputs=[z,condition], outputs=[y])

def SE_CVAE():
    encoder = SE_CVAE_encoder()
    decoder_A = SE_CVAE_decoder()
    decoder_B = SE_CVAE_decoder()
    
    x = Input(shape=(100,3))
    m = Input(shape=(100,1))
    y1= decoder_A([encoder([x,m])[0],m])
    y2= decoder_B([encoder([x,m])[0],m])
    z_mean= encoder([x,m])[1]
    z_log_var= encoder([x,m])[2]
    print(z_mean)
    
    # loss
    reconstruction_loss1 = mse(x, y1)
    reconstruction_loss2 = mse(x, y2)
    kl_loss = 0.5 * K.sum(K.square(z_mean) + K.exp(z_log_var) - z_log_var - 1, axis = -1)
    vae_loss1 = reconstruction_loss1 + kl_loss
    vae_loss2 = reconstruction_loss2 + kl_loss    

    # build model
    SE_CVAE_1 = Model(inputs=[x,m], outputs=[y1])
    SE_CVAE_2 = Model(inputs=[x,m], outputs=[y2])
    SE_CVAE_1.add_loss(vae_loss1)
    SE_CVAE_2.add_loss(vae_loss2)
    
    SE_CVAE_1.compile(optimizer='adam')
    SE_CVAE_2.compile(optimizer='adam')
    SE_CVAE_1.summary()
    SE_CVAE_2.summary()
    
    return SE_CVAE_1, SE_CVAE_2, encoder

SE_CVAE_1,SE_CVAE_2,_=SE_CVAE()
# Out:
# Tensor("model_125/z_mean/BiasAdd:0", shape=(?, 30), dtype=float32)
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_290 (InputLayer)          (None, 100, 3)       0
# __________________________________________________________________________________________________
# input_291 (InputLayer)          (None, 100, 1)       0
# __________________________________________________________________________________________________
# model_125 (Model)               [(None, 30, 1), (Non 114510      input_290[0][0]
#                                                                  input_291[0][0]
# __________________________________________________________________________________________________
# model_126 (Model)               (None, 100, 3)       110250      model_125[1][0]
#                                                                  input_291[0][0]
# ==================================================================================================
# Total params: 224,760
# Trainable params: 224,760
# Non-trainable params: 0
# __________________________________________________________________________________________________
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_290 (InputLayer)          (None, 100, 3)       0
# __________________________________________________________________________________________________
# input_291 (InputLayer)          (None, 100, 1)       0
# __________________________________________________________________________________________________
# model_125 (Model)               [(None, 30, 1), (Non 114510      input_290[0][0]
#                                                                  input_291[0][0]
# __________________________________________________________________________________________________
# model_127 (Model)               (None, 100, 3)       110250      model_125[2][0]
#                                                                  input_291[0][0]
# ==================================================================================================
# Total params: 224,760
# Trainable params: 224,760
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
pbar = tqdm(range(100))
for epoch in pbar:
    autoencoder_A.fit(first_training, first_classes, batch_size=32, nb_epoch=1)
    autoencoder_B.fit(first_training, first_classes, batch_size=32, nb_epoch=1)
    #loss_A = autoencoder_A.train_on_batch([warped_A,mask_A], [target_A,mask_A])
    #loss_B = autoencoder_B.train_on_batch([warped_B,mask_B], [target_B,mask_B])
    #pbar.set_description("Loss A [{}] Loss B [{}]".format(loss_A,loss_B))
    #Track best model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-c11776f4b46b> in <module>
# ----> 1 pbar = tqdm(range(100))
#       2 for epoch in pbar:
#       3     autoencoder_A.fit(first_training, first_classes, batch_size=32, nb_epoch=1)
#       4     autoencoder_B.fit(first_training, first_classes, batch_size=32, nb_epoch=1)
#       5     #loss_A = autoencoder_A.train_on_batch([warped_A,mask_A], [target_A,mask_A])
#
# NameError: name 'tqdm' is not defined

# %%
# Disentangling VAE

# %%
# Deep feature consistent variational auto-encoder
# using 'feature perceptual loss' instead of 'reconstruction loss'
# needs a pre-trained 'perception model'

# %%
# use domain knowledge and use multiple parallel input lambda layers for FDs, CAD, wavelets, etc

# %%
# Disentangling VAE

# Deep feature consistent variational auto-encoder
# using 'feature perceptual loss' instead of 'reconstruction loss'
# needs a pre-trained 'perception model'

# use domain knowledge and use multiple parallel input lambda layers for FDs, CAD, wavelets, etc
